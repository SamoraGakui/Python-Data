# %%
import pandas as pd
import datetime as dt

# %%
start = dt.datetime(2015, 1, 1)
end = dt.datetime.today()
start = pd.to_datetime(start)
end = pd.to_datetime(end)

# %%
start
# Out:
# Timestamp('2015-01-01 00:00:00')

# %%
import pandas_datareader.data as web

# Stock symbols
stocks = ['AAPL', 'TSLA', 'TWTR', 'IBM', 'LNKD']

# Read data from Google
df = web.DataReader(stocks, 'google', start, end)
df
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[16], line 7
#       3 # Stock symbols
#       4 stocks = ['AAPL', 'TSLA', 'TWTR', 'IBM', 'LNKD']
#       5
#       6 # Read data from Google
# ----> 7 df = web.DataReader(stocks, 'google', start, end)
#       8 df
#
# File ~/PycharmProjects/Zindua/PythonData/.venv/lib/python3.14/site-packages/pandas_datareader/compat/__init__.py:85, in deprecate_kwarg.<locals>._decorator.<locals>.wrapper(*args, **kwargs)
#      83         raise TypeError(msg)
#      84     kwargs[new_arg_name] = new_arg_value
# ---> 85 return func(*args, **kwargs)
#
# File ~/PycharmProjects/Zindua/PythonData/.venv/lib/python3.14/site-packages/pandas_datareader/data.py:98, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#      96 if data_source not in expected_source:
#      97     msg = "data_source=%r is not implemented" % data_source
# ---> 98     raise NotImplementedError(msg)
#     100 if data_source == "bankofcanada":
#     101     return BankOfCanadaReader(
#     102         symbols=name,
#     103         start=start,
#    (...)    107         session=session,
#     108     ).read()
#
# NotImplementedError: data_source='google' is not implemented

# %% [markdown]
# pandas_datareader's developers deliberately removed the Google Finance backend from the code entirely
