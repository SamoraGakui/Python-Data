# %%
import geopandas as gpd

# %% [markdown]
# Creating

# %%
from shapely.geometry import Polygon, Point, LineString

# %%
point_data = {'name': ['PointA', 'PointB', 'PointC'], 'geometry': [Point(1,3), Point(2,4), Point(3,5)]}
